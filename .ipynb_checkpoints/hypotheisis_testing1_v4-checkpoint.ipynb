# %% [markdown]
# ### Imports

# %%
# %matplotlib inline

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as stats

from scipy.stats import ttest_ind

# %% [markdown]
# #### Create Gaussian data

# %%
mu1, sigma1 = 0, 0.1 # mean and standard deviation
s1 = np.random.normal(mu1, sigma1, 100000)

mu2, sigma2 = 0, 0.1 # mean and standard deviation # sigma = 0.25
s2 = np.random.normal(mu2, sigma2, 100000)

# %% [markdown]
# #### Check normality

# %% [markdown]
# ##### Test whether a sample differs from a normal distribution.
#
# This function tests the null hypothesis that a sample comes from a normal distribution. It is based on D’Agostino and Pearson’s [1], [2] test that combines skew and kurtosis to produce an omnibus test of normality.
#
# [1] D’Agostino, R. B. (1971), “An omnibus test of normality for moderate and large sample size”, Biometrika, 58, 341-348
#
# [2] D’Agostino, R. and Pearson, E. S. (1973), “Tests for departure from normality”, Biometrika, 60, 613-622

# %%
plt.figure(figsize=(20,7))

plt.style.use('default')
#plt.style.use('seaborn-poster')
plt.style.use('ggplot')
plt.style.use('seaborn-poster')

plt.subplot(1,2,1)
sns.histplot(s1);
plt.title('s1');
print('s1: ', stats.normaltest(s1));

plt.subplot(1,2,2)
sns.histplot(s2);
plt.title('s2');
print('s2: ', stats.normaltest(s2));
# Out:
# s1:  NormaltestResult(statistic=1.291407130027317, pvalue=0.5242935377224984)
# s2:  NormaltestResult(statistic=0.912131790903286, pvalue=0.6337720730255421)

# %% [markdown]
# ### Two sampled T-test
#
# The Independent Samples t Test or 2-sample t-test compares the means of two independent groups to determine whether there is statistical evidence that the associated population means are significantly different. The Independent Samples t Test is a parametric test. Also called Independent t Test.

# %%
mu1, sigma1 = 0, 0.1 # mean and standard deviation
s1 = np.random.normal(mu1, sigma1, 10000)

mu2, sigma2 = 0, 0.1 # mean and standard deviation # 
s2 = np.random.normal(mu2, sigma2, 10000)

print('mu1,sigma1: ' + str(mu1) + ", " + str(sigma1))
print('mu2,sigma2: ' + str(mu2) + ", " + str(sigma2))

plt.style.use('default')
sns.histplot(s1, color='dodgerblue');
sns.histplot(s2, color='orange');

ttest,pval = ttest_ind(s1,s2)
print("p-value",pval)

if pval <0.05:
  print("we reject null hypothesis")
else:
  print("we accept null hypothesis")
# Out:
# mu1,sigma1: 0, 0.1
# mu2,sigma2: 0, 0.1
# p-value 0.2490626173040671
# we accept null hypothesis

# %%
mu1, sigma1 = 0, 0.1 # mean and standard deviation
s1 = np.random.normal(mu1, sigma1, 10000)

mu2, sigma2 = 0.1, 0.1 # mean and standard deviation # 
s2 = np.random.normal(mu2, sigma2, 10000)

print('mu1,sigma1: ' + str(mu1) + ", " + str(sigma1))
print('mu2,sigma2: ' + str(mu2) + ", " + str(sigma2))

sns.histplot(s1, color='dodgerblue');
sns.histplot(s2, color='orange');

ttest,pval = ttest_ind(s1,s2)
print("p-value",pval)

if pval <0.05:
  print("we reject null hypothesis")
else:
  print("we accept null hypothesis")
# Out:
# mu1,sigma1: 0, 0.1
# mu2,sigma2: 0.1, 0.1
# p-value 0.0
# we reject null hypothesis

# %% [markdown]
# ### References
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.normaltest.html
# https://towardsdatascience.com/hypothesis-testing-in-machine-learning-using-python-a0dc89e169ce

# %% [markdown]
# ### Real data

# %%
df_hit = pd.read_csv('./data/data_batters_2020to2022.csv')
df_pitch = pd.read_csv('./data/data_pitchers_2020to2022.csv')

# %%
df_hit_q = df_hit[df_hit['AB'] >=502]

# %%
alpha = 0.05
#alpha = 1e-3

# %%
sns.histplot(df_hit_q['H']);
k2, p = stats.normaltest(df_hit_q['H'])

print("null hypothesis is that sample comes from a normal distribution.")
print()
if pval < alpha:
  print("reject null hypothesis")
else:
  print("accept null hypothesis")
# Out:
# null hypothesis is that sample comes from a normal distribution.
#
# reject null hypothesis

# %% [markdown]
# ##### Take log to increase normality

# %%
sns.histplot(df_hit_q['H']);
k2, p = stats.normaltest(np.log(df_hit_q['H']))

print("null hypothesis is that sample comes from a normal distribution.")
print("p = {:g}".format(p))
if p < alpha:
  print("reject null hypothesis")
else:
  print("accept null hypothesis")
# Out:
# null hypothesis is that sample comes from a normal distribution.
# p = 0.265767
# accept null hypothesis

# %%
# under 30 vs over 30 # correlated?

# %%
df_hit_under30_q = df_hit_q[df_hit_q['Age'] < 30]
df_hit_over30_q= df_hit_q[df_hit_q['Age'] >= 30]

print(df_hit_q.shape, df_hit_under30_q.shape, df_hit_over30_q.shape)
# Out:
# (2271, 319) (1419, 319) (852, 319)

# %% [markdown]
# ##### Normality test

# %%
sns.histplot(df_hit_under30_q['H']);
plt.title('Under 30')
k2, p = stats.normaltest(df_hit_under30_q['H'])

print("null hypothesis is that sample comes from a normal distribution.")
print("p = {:g}".format(p))
if p < alpha:
  print("reject null hypothesis")
else:
  print("accept null hypothesis")
# Out:
# null hypothesis is that sample comes from a normal distribution.
# p = 3.93399e-05
# reject null hypothesis

# %%
sns.histplot(df_hit_over30_q['H']);
plt.title('Over 30')
k2, p = stats.normaltest(df_hit_over30_q['H'])

print("null hypothesis is that sample comes from a normal distribution.")
print("p = {:g}".format(p))
if p < alpha:
  print("reject null hypothesis")
else:
  print("accept null hypothesis")
# Out:
# null hypothesis is that sample comes from a normal distribution.
# p = 3.12614e-09
# reject null hypothesis

# %% [markdown]
# ### Log transform and hypothesis test

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.histplot(df_hit_under30_q['H']);
plt.title('Under 30')
plt.subplot(1,2,2)
sns.histplot(np.log(df_hit_under30_q['H']));
plt.title('Log Transformed - Under 30')
k2, p = stats.normaltest(np.log(df_hit_under30_q['H']))

print("null hypothesis is that sample comes from a normal distribution.")
print("p = {:g}".format(p))
if p < alpha:
  print("reject null hypothesis")
else:
  print("accept null hypothesis")
# Out:
# null hypothesis is that sample comes from a normal distribution.
# p = 0.156554
# accept null hypothesis

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.histplot(df_hit_over30_q['H']);
plt.title('Over 30')
plt.subplot(1,2,2)
sns.histplot(np.log(df_hit_over30_q['H']));
plt.title('Log Transformed - Over 30')
k2, p = stats.normaltest(np.log(df_hit_over30_q['H']))

print("null hypothesis is that sample comes from a normal distribution.")
print("p = {:g}".format(p))
if p < alpha:
  print("reject null hypothesis")
else:
  print("accept null hypothesis")
# Out:
# null hypothesis is that sample comes from a normal distribution.
# p = 0.676427
# accept null hypothesis

# %%
sns.histplot(np.log(df_hit_over30_q['H']), color='orange', label='over 30');
sns.histplot(np.log(df_hit_under30_q['H']), color='blue', label='under 30');
plt.legend()

# %%
sns.histplot(df_hit_over30_q['H'], color='orange', label='over 30');
sns.histplot(df_hit_under30_q['H'], color='blue', label='under 30');
plt.legend()
